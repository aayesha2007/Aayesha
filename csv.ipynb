# %% [markdown]
# <a href="https://colab.research.google.com/github/aayesha2007/Aayesha/blob/main/csv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df.head()
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes

# %%
df = pd.read_csv("/content/Data[1][1].txt")

# %%
df.isnull().sum()
# Out:
# Country      0
# Age          1
# Salary       1
# Purchased    0
# dtype: int64

# %%
df.tail()
# Out:
#    Country   Age   Salary Purchased
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
df.describe()
# Out:
#              Age        Salary
# count   9.000000      9.000000
# mean   38.777778  63777.777778
# std     7.693793  12265.579662
# min    27.000000  48000.000000
# 25%    35.000000  54000.000000
# 50%    38.000000  61000.000000
# 75%    44.000000  72000.000000
# max    50.000000  83000.000000

# %%
print("\nMissing Values in Each Column:\n", df.isnull().sum())
# Out:
# Missing Values in Each Column:
#  Country      0
# Age          1
# Salary       1
# Purchased    0
# dtype: int64

# %%
# Drop rows with missing values
df_drop = df.dropna()
print("\nDataset after Dropping Missing Rows:\n", df_drop.head())
# Out:
# Dataset after Dropping Missing Rows:
#     Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 5   France  35.0  58000.0       Yes

# %%
# Drop columns with missing values
df_drop_col = df.dropna(axis=1)
print("\nDataset after Dropping Columns with Missing Values:\n", df_drop_col.head())
# Out:
# Dataset after Dropping Columns with Missing Values:
#     Country Purchased
# 0   France        No
# 1    Spain       Yes
# 2  Germany        No
# 3    Spain        No
# 4  Germany       Yes

# %%
# Fill missing values with a constant
df_fill_const = df.fillna("Unknown")
print("\nDataset after Filling Missing Values with Constant:\n", df_fill_const.head())
# Out:
# Dataset after Filling Missing Values with Constant:
#     Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0  Unknown       Yes

# %%
# Fill missing numeric values with mean
df_fill_mean = df.fillna(df.mean(numeric_only=True))
print("\nDataset after Filling Numeric Missing Values with Mean:\n", df_fill_mean.head())
# Out:
# Dataset after Filling Numeric Missing Values with Mean:
#     Country   Age        Salary Purchased
# 0   France  44.0  72000.000000        No
# 1    Spain  27.0  48000.000000       Yes
# 2  Germany  30.0  54000.000000        No
# 3    Spain  38.0  61000.000000        No
# 4  Germany  40.0  63777.777778       Yes

# %%
# Forward fill (propagate previous values)
df_fill_forward = df.fillna(method='ffill')
print("\nDataset after Forward Fill:\n", df_fill_forward.head())
# Out:
# Dataset after Forward Fill:
#     Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0  61000.0       Yes
# /tmp/ipython-input-365635851.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_fill_forward = df.fillna(method='ffill')

# %%
# Backward fill (propagate next values)
df_fill_backward = df.fillna(method='bfill')
print("\nDataset after Backward Fill:\n", df_fill_backward.head())
# Out:
# Dataset after Backward Fill:
#     Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0  58000.0       Yes
# /tmp/ipython-input-2205219872.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_fill_backward = df.fillna(method='bfill')
